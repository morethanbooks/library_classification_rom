# %%
import sys
import os
import glob
import re 
import pandas as pd
import numpy as np
from lxml import etree
import requests
import time
from collections import Counter
import shutil

# %%
sys.path.append(os.path.abspath("C:/Users/calvotello/Dropbox/MTB/Göttingen/research/"))
sys.path.append(os.path.abspath("./../../"))

# %%
from librarian_robot import downloading_datasets, map_classications_systems, tokenize

# %%
df = pd.read_parquet("./../data/1980_2019_data.parquet")

# %%
df
# Out:
#            medium                                              title  \
# ppn
# 727067974     Aau          Glossario arabo-italiano (lingua moderna)
# 723420874     Oax  History in the Text 'Quatrevingt-Treize' and t...
# 723395780     Oax                                 Italic and Romance
# 607035692     Aau            Din stihurile jupînului François Villon
# 388767014     Aau                                The @horror of life
# ...           ...                                                ...
# 1644730073    Aau                                          Soluzioni
# 1644599279    Aau  Les @grammairiens italiens face à leur langue ...
# 1644542471    Aau                    Romance phonetics and phonology
# 1643642936    Aau  Nationale Identitätskonstruktionen in Argentinien
# 1643621785    Aau                           The @price of literature
#
#                                         title_supplement  year    entry_first  \
# ppn
# ...

# %%
df.shape
# Out:
# (366143, 59)

# %%
columns = ['title_supplement', 'summary',
 'title_continuing_resource', 'work_info',
 'work_title','expression_info',
 'expression_title', 'RVK_j', 'keyword', 'keyword_loc']

# %%
df['joined_column'] = df[columns].apply(
    lambda x: '| '.join(x.dropna().astype(str)),
    axis=1
)

# %%
df
# Out:
#            medium                                              title  \
# ppn
# 727067974     Aau          Glossario arabo-italiano (lingua moderna)
# 723420874     Oax  History in the Text 'Quatrevingt-Treize' and t...
# 723395780     Oax                                 Italic and Romance
# 607035692     Aau            Din stihurile jupînului François Villon
# 388767014     Aau                                The @horror of life
# ...           ...                                                ...
# 1644730073    Aau                                          Soluzioni
# 1644599279    Aau  Les @grammairiens italiens face à leur langue ...
# 1644542471    Aau                    Romance phonetics and phonology
# 1643642936    Aau  Nationale Identitätskonstruktionen in Argentinien
# 1643621785    Aau                           The @price of literature
#
#                                         title_supplement  year    entry_first  \
# ppn
# ...

# %%
df.to_parquet("./../data/1980_2019_data_joined.parquet")
